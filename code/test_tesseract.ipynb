# %%
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import pytesseract
import os
from PIL import Image
import csv
from image_processor import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filepath = 'D:\career\DTAS\OCR\code\OCR表格'
a = pdf_to_string(filepath)
a
# Out:
# 即将识别 5 张图片
# ['D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_03.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_05.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_14.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_21.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_41.jpg']
# mylisty [0, 78, 190, 302, 361, 391, 422, 481, 575, 635, 701, 2261]
# mylistx [0, 118, 433, 669, 905, 1142, 1378, 1616]
# 识别分割子图片信息为：0: F11
#
#
# 识别分割子图片信息为：1: Bauteil 1
# Frontklappe (engine hood)
#
#
# 识别分割子图片信息为：2: Bauteil 2
# Scheinwerfer (headlight)
#
#
# 识别分割子图片信息为：3: Fahrzeugtyp
# VW331_4
#
#
# 识别分割子图片信息为：4: Zeichnungs-Nr.
# 19D . 800 . 965
#
#
# 识别分割子图片信息为：5: Blatt 003
# von 069
#
#
# 识别分割子图片信息为：6: Maszstab
# 5:1
#
#
# 识别分割子图片信息为：7: X: -XXX‚X
#
#
# 识别分割子图片信息为：8: Y: -xxx‚x
#
#
# 识别分割子图片信息为：9: Stand
# 04.08.2016
#
#
# 识别分割子图片信息为：10: z: -xxx‚x
#
#
# 识别分割子图片信息为：11:
# 识别分割子图片信息为：12: Nennmaß
#
#
# 识别分割子图片信息为：13: Obere
# Toleranz
#
#
# 识别分割子图片信息为：14: Untere
# Toleranz
#
#
# 识别分割子图片信息为：15: Paralleli-
# taet
# ...

# %%
#test

filepath=r'D:\career\DTAS\OCR\code\OCR表格'
filelist=file_name(filepath)
print("即将识别 %d 张图片" %(len(filelist)))
print(filelist)

for filename in filelist[0:1]:
    mylisty,mylistx=get_list_xy(filename)
    a = cut_recognize(filename,mylisty,mylistx)
# Out:
# 即将识别 5 张图片
# ['D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_03.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_05.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_14.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_21.jpg', 'D:\\career\\DTAS\\OCR\\code\\OCR表格\\19D_页面_41.jpg']
# mylisty [0, 78, 190, 302, 361, 391, 422, 481, 575, 635, 701, 2261]
# mylistx [0, 118, 433, 669, 905, 1142, 1378, 1616]
# 识别分割子图片信息为：0: F11
#
#
# 识别分割子图片信息为：1: Bauteil 1
# Frontklappe (engine hood)
#
#
# 识别分割子图片信息为：2: Bauteil 2
# Scheinwerfer (headlight)
#
#
# 识别分割子图片信息为：3: Fahrzeugtyp
# VW331_4
#
#
# 识别分割子图片信息为：4: Zeichnungs-Nr.
# 19D . 800 . 965
#
#
# 识别分割子图片信息为：5: Blatt 003
# von 069
#
#
# 识别分割子图片信息为：6: Maszstab
# 5:1
#
#
# 识别分割子图片信息为：7: X: -XXX‚X
#
#
# 识别分割子图片信息为：8: Y: -xxx‚x
#
#
# 识别分割子图片信息为：9: Stand
# 04.08.2016
#
#
# 识别分割子图片信息为：10: z: -xxx‚x
#
#
# 识别分割子图片信息为：11:
# 识别分割子图片信息为：12: Nennmaß
#
#
# 识别分割子图片信息为：13: Obere
# Toleranz
#
#
# 识别分割子图片信息为：14: Untere
# Toleranz
#
#
# 识别分割子图片信息为：15: Paralleli-
# taet
# ...

# %%
CUT_PIECES = 29
#config = '-c tessedit_char_whitelist=H+'
white_list = '-c tessedit_char_whitelist=H'#äöüß0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz.,+_()-:'
for idx in range (1,CUT_PIECES + 1):
    ROI = 'cut/{}.tif'.format(idx)
    temp = pytesseract.image_to_string(ROI, config = '--psm 6 ' + white_list)
    print(temp)
# Out:
#
#    H
#
#
# H H
#  H H HHH H   HH  HHHHH         HH
#
#
# H HH HH
#
#
#
# HHH   H
# HH          H
#
#
# HHH  H
# H H
#
#
# H
#  H
#
#
#  H  HH
#
#
# H  HH
#
#
#   H
#  H H HH
#
#
#    HH
#
#
#
# H H H
#
#
#
#    H
#
#
# HH
#    H
#
#
#
#
#
#
#
#
#
#  H
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HH H
#
#
#  H
#
#
#
#
#
#
#
#
#
#
#
# H H H
#
#
# H HH
